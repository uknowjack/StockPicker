# %%
"""
v1.2

3/29/21

inspiration: https://www.youtube.com/watch?v=uWCqlo893tk

add stocks to the list that arent included like LOW

inflation target = 2%+1

add a piece that compares 1k invested today and its projected yield in 10 y

add book value, fair value, and price

Requirements: beat long term inflation, good company, good value
"""
# Out:
# '\nv1.2\n\n3/29/21\n\ninspiration: https://www.youtube.com/watch?v=uWCqlo893tk\n\nadd stocks to the list that arent included like LOW\n\ninflation target = 2%\n'

# %%
import pandas as pd
import numpy as np
import import_ipynb
import dividend_detective_scrape

import yfinance as yf

import datetime as dt

from datetime import datetime

from numpy import mean
# Out:
# importing Jupyter notebook from dividend_detective_scrape.ipynb

# %%
def trim_div_data(stockObj):
    actns = stockObj.actions
    for i,r in actns.iterrows():
        if r['Dividends'] > 0:
            first_div_date = i
            break

    actns = actns.loc[first_div_date:]
    return actns, first_div_date

# %%
def add_div_data_details(actns, first_div_date):
    actns['days_since_first_div'] = (actns.index-first_div_date).days
    actns['year'] = actns.index.year
    
    h = []
    l = []
    for i,r in actns.iterrows():
        prices = stockObj.history(start=i,end = i+pd.DateOffset(1)).iloc[0]
        h.append(prices['High'])
        l.append(prices['Low'])

    actns['Stock_High'] = h
    actns['Stock_Low'] = l
    
    actns['day_div_yield'] = actns['Dividends']/actns['Stock_High']
    return actns

# %%
def get_ind_div_data(stockObj):
    df, first_div_date = trim_div_data(stockObj)
    return add_div_data_details(df, first_div_date)

# %%
"""

then learn how long it will take to beat other investments...

"""
# Out:
# '\n\nthen learn how long it will take to beat other investments...\n\n'

# %%
def get_historical_div_info(stockObj):
    df = stockObj.actions
    df['year'] = df.index.year
    df = df[df['Dividends']>0]
    df = df.drop(columns=['Stock Splits'])
    return df

# %%
def group_divs_by_year(df):
#     combine same year divs and rename column
    ann_df = df.groupby(['year']).agg(
        {'Dividends': np.sum}).rename(columns=
        {'Dividends':'dividends'})
    start_year = ann_df.index[0]
    end_year = ann_df.index[len(ann_df)-1]+1
    ann_df = ann_df.reindex(list(range(start_year,end_year)), fill_value=0)
    return ann_df

# %%
def add_consistancy_coeff(df):
    consistancy_coeff = [1/(2**(x+1)) for x in range(len(df))][::-1]
    year_progress = datetime.now().timetuple().tm_yday/365
    consistancy_coeff[-1] = consistancy_coeff[-1]*year_progress
    
    df['div_consistency_score'] = consistancy_coeff
    return df

# %%
def calculate_div_consistency_score(df):
    
    df = add_consistancy_coeff(df)

    # default highest div is the first div
    highest_div = df.iloc[0]['dividends']
    
#     add another weight to the last cell where i get the percentage of the year we've been in and multiply it by that
# exclude 

    for i,r in df[1:-1].iterrows():      
#         i need to think about a better way to do this because right now
#         it compares the wrong two pieces
        if r['dividends'] < df.loc[i-1]['dividends']:
            mult = r['div_consistency_score']
            div_perc = r['dividends']/highest_div
            df.at[i, 'div_consistency_score'] = mult * div_perc
        else:
            highest_div = r['dividends']
    
    return df['div_consistency_score'].sum()

# %%
def structure_df(df, years):
    df = df[:-years-3:-1]
    df = df[1:]
    return df

# %%
def get_div_deltas(df):
    
    div_deltas = []
        
    for i,r in df[:-1].iterrows():
        c = float(df.loc[i]['dividends'])
        p = float(df.loc[i-1]['dividends'])

        div_deltas.append((c-p)/p)
    
    return div_deltas

# %%
def get_div_growth_rate(df, years):
    if years >= len(df)-1:
        return 0
    else:
        df = structure_df(df, years)
        
        div_deltas = get_div_deltas(df)
        
    return mean(div_deltas)

# %%
def get_div_analysis(stockObj):

    df = get_historical_div_info(stockObj)
    ann_df = group_divs_by_year(df)
    
    div_consistacy_score = calculate_div_consistency_score(ann_df)
    
    div_growth_5y = get_div_growth_rate(ann_df,5)
    div_growth_10y = get_div_growth_rate(ann_df,10)
    div_growth_15y = get_div_growth_rate(ann_df,15)

    return div_consistacy_score, div_growth_5y, div_growth_10y, div_growth_15y

# %%
def get_all_div_analysis(stockList):
    for index, row in stockList.iterrows():
        try:
            stockObj = yf.Ticker(row['ticker'])
            
            div_analysis = get_div_analysis(stockObj)
            
            div_consis, div_growth_5y, div_growth_10y, div_growth_15y = get_div_analysis(stockObj)
            
        except:
            div_consis = 0.0
            div_growth_5y = 0.0
            div_growth_10y = 0.0
            div_growth_15y = 0.0
            
        stockList.at[index, 'div_consistency_score'] = div_consis
        stockList.at[index, 'div_growth_5y'] = div_growth_5y
        stockList.at[index, 'div_growth_10y'] = div_growth_10y
        stockList.at[index, 'div_growth_15y'] = div_growth_15y
        
    return stockList

# %%
def add_div_analysis(df):
    df['yield_1k_in_10y'] = 0.0
    df['div_consistency_score'] = 0.0
    df['div_growth_5y'] = 0.0
    df['div_growth_10y'] = 0.0
    df['div_growth_15y'] = 0.0
    df = get_all_div_analysis(df)
    return df

# %%
def get_div_stocks(min_div = 3, min_consistency=.5):
    df = dividend_detective_scrape.get_data()
    
    df= df[df['div_yield']>min_div]
    
    df = add_div_analysis(df)   
    
    df = df[df['div_consistency_score']>min_consistency]
    df = df.sort_values('div_consistency_score', ascending=False)
    
    return df

# %%
df = get_div_stocks(min_div=3)
# Out:
# - CWEN.A: No data found, symbol may be delisted

# %%
df
# Out:
#     ticker                      name  annual_div  div_yield  \
# 515    UGI                       UGI        1.32        3.4
# 153    CVX                   Chevron        5.16        5.6
# 265    XOM               Exxon Mobil        3.48        6.9
# 450     SO                  Southern        2.56        4.3
# 311    GPC             Genuine Parts        3.16        3.2
# ..     ...                       ...         ...        ...
# 7     AGNC           AGNC Investment        1.44        8.8
# 123    BKE                    Buckle        1.20        3.1
# 304   GLPI  Gaming and Leisure Props        2.40        5.5
# 66     AXS     Axis Capital Holdings        1.68        3.3
# 547    VNO            Vornado Realty        2.12        5.5
#
#      div_consistency_score  div_growth_5y  div_growth_10y  div_growth_15y
# 515               0.621918       0.079676        0.076525        0.076374
# 153               0.621918       0.038580        0.062408        0.075703
# 265               0.621918       0.038724        0.072788        0.078103
# 450               0.621918       0.033518        0.034867        0.036810
# 311               0.621918       0.051506        0.068028        0.063945
# ..                     ...            ...             ...             ...
# 7                 0.508014      -0.085505       -0.115460        0.000000
# 123               0.503001       0.097949        0.314581        0.569106
# 304               0.501899      -0.040400        0.000000        0.000000
# 66                0.500895      -0.021356        0.020933        0.048211
# 547               0.500673       0.113154        0.071983        0.024774
#
# [304 rows x 8 columns]

# %%
fdf = df

# %%
fdf = fdf.query('div_growth_5y >= 0.03 & div_growth_10y >= 0.03 & div_growth_15y >= 0.03')
# Out:
#     ticker                       name  annual_div  div_yield  \
# 515    UGI                        UGI        1.32        3.4
# 153    CVX                    Chevron        5.16        5.6
# 265    XOM                Exxon Mobil        3.48        6.9
# 450     SO                   Southern        2.56        4.3
# 311    GPC              Genuine Parts        3.16        3.2
# ..     ...                        ...         ...        ...
# 532   VALE                       Vale        0.69        3.9
# 241    CIG  Energy Co of Minas Gerais        0.12        4.7
# 135   CSWC          Capital Southwest        1.68        8.2
# 478     SU              Suncor Energy        0.65        3.6
# 123    BKE                     Buckle        1.20        3.1
#
#      div_consistency_score  div_growth_5y  div_growth_10y  div_growth_15y
# 515               0.621918       0.079676        0.076525        0.076374
# 153               0.621918       0.038580        0.062408        0.075703
# 265               0.621918       0.038724        0.072788        0.078103
# 450               0.621918       0.033518        0.034867        0.036810
# 311               0.621918       0.051506        0.068028        0.063945
# ..                     ...            ...             ...             ...
# 532               0.550286       1.381945        0.751478        0.561938
# 241               0.546429       0.046888        0.082945        0.293882
# 135               0.546371       1.140225        2.560702        1.952383
# 478               0.521394       0.051444        0.121587        0.182876
# 123               0.503001       0.097949        0.314581        0.569106
#
# [109 rows x 8 columns]

# %%
fdf = fdf.query('div_growth_5y > div_growth_10y & div_growth_10y > div_growth_15y')

# %%
fdf.sort_values('div_yield', ascending=False)
# Out:
#     ticker                      name  annual_div  div_yield  \
# 215    DHT              DHT Holdings        1.08       18.1
# 239    ENB                  Enbridge        2.61        7.6
# 152    CQP  Cheniere Energy Partners        2.62        6.6
# 110    BDN   Brandywine Realty Trust        0.76        6.3
# 526    UVV                 Universal        3.08        6.0
# 486    TRP                 TC Energy        2.52        5.7
# 547    VNO            Vornado Realty        2.12        5.5
# 361    HIW      Highwoods Properties        1.92        4.8
# 393    PFS       Provident Financial        0.92        4.7
# 234    EIX               Edison Intl        2.65        4.6
# 244    EBF                     Ennis        0.90        4.6
# 554   WASH  Washington Trust Bancorp        2.08        4.5
# 410    REG           Regency Centers        2.38        4.5
# 181    CMA                  Comerica        2.72        4.4
# 190     ED       Consolidated Edison        3.10        4.4
# 226    DUK               Duke Energy        3.86        4.3
# 457     SR                     Spire        2.60        4.1
# 508   TRST              Trustco Bank        0.27        4.0
# 425   STBA               S&T Bancorp        1.12        4.0
# 532   VALE                      Vale        0.69        3.9
# 346     HE   Hawaiian Electric Indus        1.36        3.9
# 285   FIBK  First Interstate BancSys        1.64        3.8
# 117    BIP  Brookfield Infr Partners        1.94        3.8
# 26     AEP   American Electric Power        2.96        3.8
# 9      ADC              Agree Realty        2.48        3.8
# 92     BKH               Black Hills        2.26        3.7
# 253    EQR        Equity Residential        2.41        3.6
# 225    DTE                DTE Energy        4.34        3.6
# 525    UTL                    Unitil        1.52        3.6
# 121   BRKL         Brookline Bancorp        0.46        3.5
# 384    IMO              Imperial Oil        0.68        3.4
# 515    UGI                       UGI        1.32        3.4
# 207   CVBF             CVB Financial        0.72        3.4
# 71     BKR              Baker Hughes        0.72        3.2
# 268   FMNB     Farmers National Banc        0.44        3.2
# 237    EIG        Employers Holdings        1.00        3.2
# 482    SNV              Synovus Finl        1.32        3.2
# 256    ESS      Essex Property Trust        8.31        3.1
# 130    CPT         Camden Prop Trust        3.32        3.1
# 503     TG                  Tredegar        0.48        3.1
#
#      div_consistency_score  div_growth_5y  div_growth_10y  div_growth_15y
# 215               0.541010       1.254263        1.030651        0.000000
# 239               0.596830       0.156295        0.142153        0.135009
# 152               0.621887       0.090146        0.045073        0.000000
# 110               0.621833       0.049229        0.024615       -0.021917
# 526               0.621918       0.083317        0.051871        0.042164
# 486               0.620304       0.058630        0.055622        0.050977
# 547               0.500673       0.113154        0.071983        0.024774
# 361               0.612666       0.052661        0.026331        0.017554
# 393               0.569881       0.094234        0.087726        0.081370
# 234               0.621916       0.109444        0.072608        0.060200
# 244               0.593453       0.339560        0.269890        0.179926
# 554               0.621896       0.104460        0.091831        0.079368
# 410               0.621796       0.041844        0.025625        0.010055
# 181               0.621799       0.291306        0.288029        0.151779
# 190               0.621918       0.033120        0.025500        0.019874
# 226               0.621913       0.033514        0.027618        0.018502
# 457               0.621918       0.061434        0.047228        0.041066
# 508               0.621688       0.006015        0.005333       -0.044504
# 425               0.621730       0.091116        0.066053        0.015363
# 532               0.550286       1.381945        0.751478        0.561938
# 346               0.621918       0.012702        0.006351        0.004234
# 285               0.621355       0.215524        0.180836        0.000000
# 117               0.563612       0.198576        0.169636        0.000000
# 26                0.621916       0.057274        0.052183        0.047477
# 9                 0.621812       0.054473        0.020300        0.016215
# 92                0.621918       0.060286        0.042082        0.036015
# 253               0.595432       0.845343        0.465256        0.300288
# 225               0.621918       0.077513        0.065954        0.047787
# 525               0.621918       0.013894        0.008396        0.005598
# 121               0.621509       0.054137        0.039814       -0.016167
# 384               0.607689       0.136657        0.069763        0.066516
# 515               0.621918       0.079676        0.076525        0.076374
# 207               0.613440       0.137131        0.104716        0.090629
# 71                0.561892       4.957916        2.491875        1.677456
# 268               0.621061       0.299306        0.166320        0.049213
# 237               0.621887       0.347273        0.173636        0.000000
# 482               0.621806       0.271905        0.182151        0.086684
# 256               0.621918       0.088661        0.066647        0.062837
# 130               0.585039       0.225863        0.141173        0.083669
# 503               0.620534       2.622963        1.731481        1.154321

# %%
fdf.shape
# Out:
# (40, 8)
