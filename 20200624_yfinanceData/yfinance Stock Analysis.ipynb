# %%
"""
v0.1 stock valuation

this program is intended to be split into 2-3 parts

the first part is finding the stock's value to me. specifically by figuring out the roi on 
dividends of the companies that have had increasing dividends for a certain amount of time
"""
# Out:
# "\nv0.1 stock valuation\n\nthis program is intended to be split into 2-3 parts\n\nthe first part is finding the stock's value to me. specifically by figuring out the roi on \ndividends of the companies that have had increasing dividends for a certain amount of time\n"

# %%
import yfinance as yf

# %%
stock = yf.Ticker("msft")

# %%
stock.history(period="max")
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.06    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# ...            ...     ...     ...     ...         ...        ...
# 2020-06-15  184.58  190.82  184.01  188.94    32770200        0.0
# 2020-06-16  192.89  195.58  191.46  193.57    42556700        0.0
# 2020-06-17  195.03  196.32  193.69  194.24    25655900        0.0
# 2020-06-18  194.00  196.49  194.00  196.32    23061600        0.0
# 2020-06-19  198.59  199.29  194.37  195.15    44423500        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# ...

# %%
stock.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-09-21       0.00           2.0
# 1990-04-16       0.00           2.0
# 1991-06-27       0.00           1.5
# 1992-06-15       0.00           1.5
# 1994-05-23       0.00           2.0
# ...               ...           ...
# 2019-05-15       0.46           0.0
# 2019-08-14       0.46           0.0
# 2019-11-20       0.51           0.0
# 2020-02-19       0.51           0.0
# 2020-05-20       0.51           0.0
#
# [75 rows x 2 columns]

# %%
stock.dividends
# Out:
# Date
# 2003-02-19    0.08
# 2003-10-15    0.16
# 2004-08-23    0.08
# 2004-11-15    3.08
# 2005-02-15    0.08
#               ...
# 2019-05-15    0.46
# 2019-08-14    0.46
# 2019-11-20    0.51
# 2020-02-19    0.51
# 2020-05-20    0.51
# Name: Dividends, Length: 66, dtype: float64

# %%
stock.major_holders
# Out:
#         0                                      1
# 0   1.42%        % of Shares Held by All Insider
# 1  74.09%       % of Shares Held by Institutions
# 2  75.16%        % of Float Held by Institutions
# 3    4630  Number of Institutions Holding Shares

# %%
stock.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
# ...

# %%
stock.balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
stock.cashflow
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
